# %% [markdown]
# # Sorting

# %%
import ten
ten.set_seed(123)

# %%
x = ten.rand_unif([10], -1., 1.)
x
# Out:
# tensor<float32,10>
# 0.392938
# 0.425911
# -0.427721
# -0.143058
# -0.546297
# 0.38177
# 0.10263
# 0.438301
# 0.438938
# -0.0177621

# %%
# Sort a tensor, returns a new sorted tensor
ten.sort(x)
# Out:
# tensor<float32,10>
# -0.546297
# -0.427721
# -0.143058
# -0.0177621
# 0.10263
# 0.38177
# 0.392938
# 0.425911
# 0.438301
# 0.438938

# %%
# Sort the tensor inplace
ten.sort_inplace(x)
x
# Out:
# tensor<float32,10>
# -0.546297
# -0.427721
# -0.143058
# -0.0177621
# 0.10263
# 0.38177
# 0.392938
# 0.425911
# 0.438301
# 0.438938
